# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import plotly.express as px
#import holoviews as hv
#from ggplot import *


# Red wine dataset

df = pd.read_csv("/Users/dilarabursa/Desktop/TechLabsDUS_WineNot/TechLabsDUS_WineNot-1/data/raw/winequality-red.csv", sep=";")
display(df)

#df = pd.read_csv("/Users/dilarabursa/Desktop/TechLabsDUS_WineNot/TechLabsDUS_WineNot-1/data/raw/winequality-white.csv", sep=";")
#display(df)

plt.hist(df['fixed acidity'], bins=6)
plt.xlabel('pH')
plt.ylabel('Häufigkeit')
plt.title('Histogramm of fixed acidity')
plt.show()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...
